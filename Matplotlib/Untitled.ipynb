# %%
! pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[5,6,4,8,3,]

# %%
plt. plot (x,y)

# %%
plt.plot(x,y)
plt.xlabel("X values")
plt.ylabel("y values")
plt.title("x values, y values")
# Out:
# Text(0.5, 1.0, 'x values, y values')

# %%
## a histogram displays shape and spread of continous sample data

# %%
ab=[10,22,36,48]
plt.hist(ab,color = 'red')
# Out:
# (array([1., 0., 0., 1., 0., 0., 1., 0., 0., 1.]),
#  array([10. , 13.8, 17.6, 21.4, 25.2, 29. , 32.8, 36.6, 40.4, 44.2, 48. ]),
#  <BarContainer object of 10 artists>)
